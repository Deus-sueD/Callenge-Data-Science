# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %%
tienda2.head()
# Out:
#            Producto  Categoría del Producto    Precio  Costo de envío  \
# 0  Silla de oficina                 Muebles  283600.0         15300.0
# 1         Pandereta  Instrumentos musicales   76800.0          2300.0
# 2         Cama king                 Muebles  443300.0         23800.0
# 3         Cama king                 Muebles  906200.0         46400.0
# 4  Silla de oficina                 Muebles  397800.0         19400.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      04/08/2021  Izabela de León        Medellín             1
# 1      26/11/2020   Blanca Ramirez        Medellín             3
# 2      22/10/2021  Izabela de León         Pereira             5
# 3      04/05/2022    Maria Alfonso            Cali             5
# 4      26/02/2022    Lucas Olivera          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0               Nequi                   1  6.25184 -75.56359
# ...

# %%
tienda3.head()
# Out:
#             Producto  Categoría del Producto     Precio  Costo de envío  \
# 0   Secadora de ropa       Electrodomésticos  1285100.0         66600.0
# 1      Mesa de noche                 Muebles   290100.0         13600.0
# 2  Guitarra acústica  Instrumentos musicales   303500.0         17400.0
# 3  Balón de voleibol    Deportes y diversión    58800.0          3300.0
# 4            Armario                 Muebles   521100.0         25900.0
#
#   Fecha de Compra        Vendedor Lugar de Compra  Calificación  \
# 0      17/12/2021   Camila Rivera     Santa Marta             4
# 1      10/02/2021   Maria Alfonso            Cali             3
# 2      22/01/2023   Lucas Olivera          Bogotá             5
# 3      22/03/2022     Pedro Gomez    Barranquilla             4
# 4      12/01/2022  Blanca Ramirez          Bogotá             1
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   4  11.24079 -74.19904
# ...

# %%
tienda4.head()
# Out:
#               Producto Categoría del Producto     Precio  Costo de envío  \
# 0         Lavavajillas      Electrodomésticos  1084800.0         56000.0
# 1             Cama box                Muebles   473800.0         25400.0
# 2  Balón de baloncesto   Deportes y diversión    23700.0             0.0
# 3  Modelado predictivo                 Libros    57700.0          1300.0
# 4          Auriculares           Electrónicos   138900.0          5600.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      11/11/2022    Rafael Acosta          Bogotá             4
# 1      03/01/2020  Izabela de León          Cúcuta             5
# 2      25/12/2022    Maria Alfonso        Medellín             5
# 3      23/11/2021    Lucas Olivera        Medellín             3
# 4      25/04/2022   Blanca Ramirez          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0  Tarjeta de crédito                   3  4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
from matplotlib import pyplot as plt

def graficar(tienda):
  Tiendasportabla = tienda['Lugar de Compra']
  Tiendasunicasportabla = list(set(Tiendasportabla))

  ventastotales = []
  ventasportienda = []

  for x in Tiendasunicasportabla:
    #Agrega a una lista de tuplas los valores de la ciudad y ademas todos los valores de venta
    ventasportienda.append((x,tienda[tienda['Lugar de Compra'] == x]['Precio']))
    #Agrega a una lista de tuplas los valores de la ciudad y la suma de todas sus ventas
    ventastotales.append((x,float(tienda[tienda['Lugar de Compra'] == x]['Precio'].sum())))

  #Separamos la lista de tupplas con zip
  ciudad, venta = zip(*ventastotales)

  #definimos el tamaño de la grafica

  fig_width = max(10, len(ciudad))
  fig_height = 5
  plt.figure(figsize=(fig_width, fig_height))

  #Imprimimos grafica
  plt.bar(ciudad, venta)
  plt.title('Ventas por tienda')
  plt.xlabel('Tiendas')
  plt.ylabel('Ventas')

  #mostrar las etiquetas de x verticalmente
  plt.xticks(rotation=90)

  #ajusta el tamaño de las etiquetas

  #formatear el eje y para que muestre valores de miles(ambas formas son lo mismo)
  #plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))
  plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f"{int(x):,}"))
  plt.tight_layout()
  plt.show()

def Tiendaspordf(tienda):
  Tiendasunicasportabla = list(set(tienda['Lugar de Compra']))

  ventastotales = [(x,float(tienda[tienda['Lugar de Compra'] == x]['Precio'].sum())) for x in Tiendasunicasportabla]
  '''
  Si quereemos retornar de mayor a menor:
  return sorted(ventastotales, key=lambda x: x[1], reverse=True)
  '''
  #Retornamos de menor a mayor las ventas
  return sorted(ventastotales, key=lambda x: x[1])

def graficardemayoraminor(ventasxtienda,Titulodelgrafico,labelx,labely):
  ciudad, venta = zip(*ventasxtienda)
  fig_width = max(10, len(ciudad))
  fig_height = 5
  plt.figure(figsize=(fig_width, fig_height))
  plt.bar(ciudad, venta)
  plt.title(f'{Titulodelgrafico}')
  plt.xlabel(f'{labelx}')
  plt.ylabel(f'{labely}')
  plt.xticks(rotation=90)
  plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f"{int(x):,}"))
  plt.tight_layout()
  plt.show()
  return

def Graficadepastel(tienda,Titulodelgrafico):
  import matplotlib.pyplot as plt

  Nombres = [nombre for nombre, _ in tienda]
  Ventas = [ventas for _, ventas in tienda]

  plt.pie(Ventas, labels=Nombres, autopct='%1.1f%%', startangle=90)
  plt.axis('equal')
  plt.title(Titulodelgrafico)
  plt.show()

# %%
print(Tiendaspordf(tienda))
print(Tiendaspordf(tienda2))
print(Tiendaspordf(tienda3))
print(Tiendaspordf(tienda4))
# Out:
# [('Valledupar', 1121300.0), ('Inírida', 2722500.0), ('Neiva', 3494000.0), ('Soacha', 4126000.0), ('Armenia', 4615700.0), ('Villavicencio', 7161900.0), ('Manizales', 8027600.0), ('Santa Marta', 13198300.0), ('Leticia', 14669800.0), ('Pasto', 14996400.0), ('Bucaramanga', 17579200.0), ('Riohacha', 18512700.0), ('Cartagena', 22296700.0), ('Barranquilla', 32907700.0), ('Cúcuta', 37879500.0), ('Pereira', 56214300.0), ('Cali', 154493700.0), ('Medellín', 296858100.0), ('Bogotá', 440005000.0)]
# [('Valledupar', 1099800.0), ('Soacha', 2240700.0), ('Inírida', 2504600.0), ('Armenia', 3363200.0), ('Manizales', 3539900.0), ('Villavicencio', 3597100.0), ('Neiva', 3839400.0), ('Riohacha', 12656400.0), ('Pasto', 12800100.0), ('Santa Marta', 13829300.0), ('Leticia', 16159000.0), ('Cartagena', 21548300.0), ('Bucaramanga', 23895600.0), ('Barranquilla', 27741300.0), ('Cúcuta', 28991500.0), ('Pereira', 43073800.0), ('Cali', 118257600.0), ('Medellín', 297246700.0), ('Bogotá', 479959200.0)]
# ...

# %%
tiendasgral = pd.concat([tienda,tienda2,tienda3,tienda4])
tiendasgral
# Out:
#                 Producto   Categoría del Producto    Precio  Costo de envío  \
# 0      Asistente virtual             Electrónicos  164300.0          6900.0
# 1        Mesa de comedor                  Muebles  192300.0          8400.0
# 2          Juego de mesa                 Juguetes  209600.0         15900.0
# 3             Microondas        Electrodomésticos  757500.0         41000.0
# 4       Silla de oficina                  Muebles  335200.0         20200.0
# ...                  ...                      ...       ...             ...
# 2353     Mesa de comedor                  Muebles  227700.0         12600.0
# 2354    Silla de oficina                  Muebles  342000.0         18600.0
# 2355        Vaso térmico     Deportes y diversión   36700.0          2400.0
# 2356        Set de ollas  Artículos para el hogar  151800.0          8300.0
# 2357  Cuerda para saltar     Deportes y diversión   11200.0          1300.0
#
# ...

# %%
print(Tiendaspordf(tiendasgral))
graficardemayoraminor(Tiendaspordf(tiendasgral),'Ventas por zona','Tiendas','Ventas')
# Out:
# [('Valledupar', 5886300.0), ('Inírida', 8087900.0), ('Armenia', 12242900.0), ('Soacha', 12317700.0), ('Villavicencio', 13333600.0), ('Manizales', 19367900.0), ('Neiva', 20898000.0), ('Pasto', 49014300.0), ('Santa Marta', 53100500.0), ('Leticia', 67149900.0), ('Riohacha', 73879700.0), ('Bucaramanga', 90573300.0), ('Cúcuta', 99369100.0), ('Cartagena', 102376700.0), ('Barranquilla', 132040500.0), ('Pereira', 225927300.0), ('Cali', 506526100.0), ('Medellín', 1096669200.0), ('Bogotá', 1814858300.0)]

# %% [markdown]
# # 2. Ventas por categoría

# %%
def Ventasporcategoriaxtienda(tienda):
  Categoriaportabla = list(set(tienda['Categoría del Producto']))

  Categoriadelproductoportabla = list(tienda['Categoría del Producto'])
  contador = [Categoriadelproductoportabla.count(x) for x in Categoriaportabla]
  ventastotales = zip(Categoriaportabla, contador)

  #Retornamos de menor a mayor las ventas
  return sorted(ventastotales, key=lambda x: x[1])

# %%
#graficardemayoraminor(Ventasporcategoriaxtienda(tiendasgral), 'Ventas por categoria', 'Categoria','Ventas')
Graficadepastel(Ventasporcategoriaxtienda(tiendasgral),'Ventas por categoria')

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
def CalificacionPorTienda(tienda):
  Tiendasunicasportabla = list(set(tienda['Lugar de Compra']))

  Contador = [(float(tienda[tienda['Lugar de Compra'] == x]['Calificación'].count())) for x in Tiendasunicasportabla]
  Califtotales = {x : float(tienda[tienda['Lugar de Compra'] == x]['Calificación'].sum()) for x in Tiendasunicasportabla}

  tienda, sumadecalifiaciones = zip(*Califtotales.items())
  Califtotales = zip(tienda, [x/y for x,y in zip(sumadecalifiaciones,Contador)])
  #Retornamos de menor a mayor las ventas
  return sorted(Califtotales, key=lambda x: x[1])

# %%
graficardemayoraminor(CalificacionPorTienda(tiendasgral), 'Calificacion de ciudades', 'Ciudad','Calificación')

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
def Productosmastomenos(tienda):
  Productosunicosportabla = list(set(tienda['Producto']))
  Productosporseparado = list(tienda['Producto'])

  Contador = [Productosporseparado.count(x) for x in Productosunicosportabla]
  masvendidos = [(Productosunicosportabla[x], Contador[x]) for x in range(len(Productosunicosportabla))]

  '''
  Si quereemos retornar de mayor a menor:
  return sorted(ventastotales, key=lambda x: x[1], reverse=True)
  '''
  #Retornamos de menor a mayor las ventas
  return sorted(masvendidos, key=lambda x: x[1])

def Graficadedispersion(tienda,titulo_del_grafico,label_y):
  # Crear índice numérico para el eje X
  indices = list(range(len(tienda)))
  nombres, valores = zip(*tienda)

  # Crear gráfico de dispersión
  plt.figure(figsize=(14, 6))
  plt.scatter(indices, valores, color='green', s=60)
  plt.xticks(indices, nombres, rotation=90)
  plt.ylabel(label_y)
  plt.title(titulo_del_grafico)
  plt.tight_layout()
  plt.grid(True)
  plt.show()

# %%
print(Productosmastomenos(tiendasgral))
'''
Grafica de barras:
graficardemayoraminor(Productosmastomenos(tiendasgral), 'Productos mas vendidos', 'Productos','Ventas')
Graficadedispersion(Productosmastomenos(tienda), 'Productos mas vendidos', 'Ventas')
Graficadedispersion(Productosmastomenos(tienda2), 'Productos mas vendidos', 'Ventas')
Graficadedispersion(Productosmastomenos(tienda3), 'Productos mas vendidos', 'Ventas')
Graficadedispersion(Productosmastomenos(tienda4), 'Productos mas vendidos', 'Ventas')
'''
Graficadedispersion(Productosmastomenos(tiendasgral), 'Productos mas vendidos', 'Ventas')
# Out:
# [('Celular ABXY', 157), ('Auriculares con micrófono', 158), ('Mochila', 163), ('Guitarra eléctrica', 165), ('Ciencia de datos con Python', 166), ('Asistente virtual', 167), ('Sillón', 168), ('Set de vasos', 169), ('Smartwatch', 172), ('Olla de presión', 172), ('Auriculares', 174), ('Mesa de centro', 175), ('Muñeca bebé', 175), ('Juego de mesa', 175), ('Dinosaurio Rex', 175), ('Lavadora de ropa', 176), ('Tablet ABXY', 179), ('Cubo mágico 8x8', 180), ('Ajedrez de madera', 180), ('Silla de oficina', 181), ('Dashboards con Power BI', 181), ('Sofá reclinable', 182), ('Balón de voleibol', 184), ('Mesa de comedor', 185), ('Cuerda para saltar', 186), ('Vaso térmico', 187), ('Estufa', 187), ('TV LED UHD 4K', 187), ('Impresora', 188), ('Kit de bancas', 188), ('Guitarra acústica', 188), ('Cubertería', 189), ('Lavavajillas', 189), ('Refrigerador', 191), ('Smart TV', 192), ('Iniciando en programación', 195), ('Bicicleta', 196), ('Armario', 197), ('Balón de baloncesto', 197), ('Pandereta', 197), (
# ...

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
def EnvioPromedio(tienda):
  Tiendasunicasportabla = list(set(tienda['Lugar de Compra']))

  Contador = [(float(tienda[tienda['Lugar de Compra'] == x]['Costo de envío'].count())) for x in Tiendasunicasportabla]
  Enviototales = {x : float(tienda[tienda['Lugar de Compra'] == x]['Costo de envío'].sum()) for x in Tiendasunicasportabla}

  tienda, sumadeenvio = zip(*Enviototales.items())
  Enviototales = zip(tienda, [x/y for x,y in zip(sumadeenvio,Contador)])
  #Retornamos de menor a mayor las ventas
  return sorted(Enviototales, key=lambda x: x[1])

# %%
EnvioPromedio(tiendasgral)
# Out:
# [('Santa Marta', 18752.3178807947),
#  ('Valledupar', 22021.428571428572),
#  ('Cartagena', 22638.429752066117),
#  ('Barranquilla', 22692.25806451613),
#  ('Armenia', 22867.85714285714),
#  ('Pereira', 23211.411992263056),
#  ('Riohacha', 24127.60736196319),
#  ('Bogotá', 24532.082170935835),
#  ('Manizales', 24948.780487804877),
#  ('Villavicencio', 25100.0),
#  ('Medellín', 25282.022471910113),
#  ('Leticia', 25317.605633802817),
#  ('Cali', 26726.812313803377),
#  ('Bucaramanga', 26790.055248618784),
#  ('Neiva', 27710.0),
#  ('Pasto', 27801.063829787236),
#  ('Cúcuta', 28597.31182795699),
#  ('Inírida', 30557.14285714286),
#  ('Soacha', 34768.42105263158)]

# %%
graficardemayoraminor(EnvioPromedio(tiendasgral), 'Costo de Envio promedio de Tiendas', 'Ciudad','Costo promedio de Envio')

# %% [markdown]
# #Informe final

# %% [markdown]
# Para elegir correctamente que tienda se deberá vender se realizó un analisis sobre las tiendas y las respectivas ciudades en las que se encuentran, se analizó la cantidad de ingresos totales por área obteniendo que la tienda que genera menos ingresos es Valledupar con un ingreso promedio de 5,886,300.0 pesos como lo muestra el siguiente grafico:

# %%
graficardemayoraminor(Tiendaspordf(tiendasgral),'Ventas por zona','Tiendas','Ventas')

# %% [markdown]
# A pesar de esto encontramos que la venta por categorias se encuentra la siguiente distribución:

# %%
Graficadepastel(Ventasporcategoriaxtienda(tiendasgral),'Ventas por categoria')

# %% [markdown]
# Por otro lado si analisamos la calificación promedio por tienda podemos notar que Vallelupar no se encuentra con mala calificación, como se puede observar en la siguiente grafica:

# %%
graficardemayoraminor(CalificacionPorTienda(tiendasgral), 'Calificacion de ciudades', 'Ciudad','Calificación')

# %% [markdown]
# Siendo Armenia la tienda con menor calificación, sin embargo pese a ello, sigue facturando aun más que Vallelupar.
#
# Por otro lado si analizamos la cantidad obtenida mediante los envios nos daremos cuenta que Vallelupar es la segunda más baja con 22021.42 pesos, superando ligeramente a Santa Marta, como se puede analizar en la siguiente grafica:

# %%
graficardemayoraminor(EnvioPromedio(tiendasgral), 'Costo de Envio promedio de Tiendas', 'Ciudad','Costo promedio de Envio')

# %% [markdown]
# Con base en lo anterior, pese a que Santa Marta tiene una calificación menor y una cantidad de envios menor que Vallelupar, su facturación resulta mayor, por lo tanto la tienda que deberia vender el Sr. Joao deberia ser Vallelupar.
